# %%
print("Name: Pooja P Rawool")
print("ERP ID: 1132200081")
# Out:
# Name: Pooja P Rawool
# ERP ID: 1132200081

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
from sklearn.model_selection import train_test_split

# %%
# %cd D:\MSC\Trimester3\ML2\Datasets
# Out:
# D:\MSC\Trimester3\ML2\Datasets

# %% [markdown]
# # Iris

# %%
data=pd.read_json('iris.json')

# %%
data.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
data.shape
# Out:
# (150, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sepalLength  150 non-null    float64
#  1   sepalWidth   150 non-null    float64
#  2   petalLength  150 non-null    float64
#  3   petalWidth   150 non-null    float64
#  4   species      150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.describe()
# Out:
#        sepalLength  sepalWidth  petalLength  petalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.057333     3.758000    1.199333
# std       0.828066    0.435866     1.765298    0.762238
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
data["species"].value_counts()
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %%
data.hist(bins=50,figsize=(10,15))
# Out:
# array([[<AxesSubplot:title={'center':'sepalLength'}>,
#         <AxesSubplot:title={'center':'sepalWidth'}>],
#        [<AxesSubplot:title={'center':'petalLength'}>,
#         <AxesSubplot:title={'center':'petalWidth'}>]], dtype=object)

# %%
import seaborn as sns
sns.pairplot(data,hue="species")

# %%
corr_matrix=data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='YlGnBu');

# %%
y=data["species"]
x=data.drop(["species"],axis=1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
x_train.shape,y_train.shape
# Out:
# ((120, 4), (120,))

# %%
x_test.shape,y_test.shape
# Out:
# ((30, 4), (30,))

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.9666666666666667

# %%
y_test[:10]
# Out:
# 114     virginica
# 62     versicolor
# 33         setosa
# 107     virginica
# 7          setosa
# 100     virginica
# 40         setosa
# 86     versicolor
# 76     versicolor
# 71     versicolor
# Name: species, dtype: object

# %%
y_pred[:10]
# Out:
# array(['virginica', 'versicolor', 'setosa', 'virginica', 'setosa',
#        'virginica', 'setosa', 'versicolor', 'versicolor', 'versicolor'],
#       dtype='<U10')

# %%
model.predict_proba(x_test)
# Out:
# array([[1.63372928e-232, 2.18878257e-006, 9.99997811e-001],
#        [1.82639310e-082, 9.99998304e-001, 1.69618339e-006],
#        [1.00000000e+000, 7.10249611e-019, 3.65449343e-028],
#        [1.58504237e-305, 1.04649001e-006, 9.99998954e-001],
#        [1.00000000e+000, 8.59167700e-017, 4.22158885e-027],
#        [6.39815011e-321, 1.56450155e-010, 1.00000000e+000],
#        [1.00000000e+000, 1.09797209e-016, 5.30276005e-027],
#        [1.25120755e-146, 7.74052118e-001, 2.25947882e-001],
#        [5.34350034e-150, 9.07564965e-001, 9.24350350e-002],
#        [5.67255124e-093, 9.99882109e-001, 1.17891089e-004],
#        [2.38647840e-210, 5.29609668e-001, 4.70390332e-001],
#        [8.12034334e-132, 9.43762578e-001, 5.62374220e-002],
#        [5.25172112e-132, 9.98864362e-001, 1.13563826e-003],
#        [1.24495991e-139, 9.49838645e-001, 5.01613550e-002],
#        [4.08227091e-140, 9.88043865e-001, 1.19561349e-002],
#        [1.00000000e+000, 7.12836412e-019, 4.10162293e-029],
# ...

# %% [markdown]
# # Fish_Modified

# %%
data=pd.read_csv('Fish_Modified.csv')

# %%
data.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 3   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 4   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555

# %%
data["Length"]=(data["Length1"]+data["Length2"]+data["Length3"])

# %%
data.drop(["Length1","Length2","Length3"],axis=1,inplace=True)

# %%
data.head()
# Out:
#   Species  Weight   Height   Width  Length
# 0   Bream   242.0  11.5200  4.0200    78.6
# 1   Bream   290.0  12.4800  4.3056    81.5
# 2   Bream   290.0  12.4800  4.3056    81.5
# 3   Bream   340.0  12.3778  4.6961    81.5
# 4   Bream   363.0  12.7300  4.4555    88.8

# %%
data.describe()
# Out:
#             Weight      Height       Width      Length
# count   163.000000  163.000000  163.000000  163.000000
# mean    396.941893    9.006893    4.502990   86.065905
# std     357.010485    4.352748    1.758922   32.111258
# min       0.000000    1.738800    1.047600   24.700000
# 25%     120.000000    5.926950    3.525000   64.486792
# 50%     273.000000    7.786000    4.335000   81.500000
# 75%     635.500000   12.379300    5.602222  107.650000
# max    1650.000000   20.000000   12.000000  190.400000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  163 non-null    object
#  1   Weight   163 non-null    float64
#  2   Height   163 non-null    float64
#  3   Width    163 non-null    float64
#  4   Length   163 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 6.5+ KB

# %%
index=data[data["Weight"]==0].index

# %%
data.drop(index , inplace=True)

# %%
data.shape
# Out:
# (162, 5)

# %%
data.describe()
# Out:
#             Weight      Height       Width      Length
# count   162.000000  162.000000  162.000000  162.000000
# mean    399.392152    9.022521    4.510097   86.200879
# std     356.740030    4.361656    1.762026   32.164412
# min       5.900000    1.738800    1.047600   24.700000
# 25%     120.000000    5.922225    3.525000   64.725000
# 50%     281.500000    7.789000    4.351500   81.650000
# 75%     642.750000   12.380050    5.602222  107.675000
# max    1650.000000   20.000000   12.000000  190.400000

# %%
data.hist(bins=50,figsize=(10,15))
# Out:
# array([[<AxesSubplot:title={'center':'Weight'}>,
#         <AxesSubplot:title={'center':'Height'}>],
#        [<AxesSubplot:title={'center':'Width'}>,
#         <AxesSubplot:title={'center':'Length'}>]], dtype=object)

# %%
import seaborn as sns
sns.pairplot(data,hue="Species")

# %%
corr_matrix=data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='YlGnBu');

# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure()
plt.figure(figsize=(20,10))
ax=plt.axes(projection="3d")
x=data["Height"]
y=data["Width"]
z=data["Length"]
colors={"Bream":'red',"Parkki":'blue',"Perch":'green',"Pike":'black',"Roach":'yellow',"Smelt":'orange',"Whitefish":'violet'}
ax.scatter3D(x,y,z,c=data["Species"].apply(lambda x: colors[x]))

# %%
retval=data.boxplot(by="Species",figsize=(20,20))

# %% [markdown]
# # Naive Bayes without removal of outliers

# %%
y=data["Species"]
x=data.drop(["Species"],axis=1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
x_train.shape,y_train.shape
# Out:
# ((129, 4), (129,))

# %%
x_test.shape,y_test.shape
# Out:
# ((33, 4), (33,))

# %% [markdown]
# ## Without StandardScaler

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.45454545454545453

# %%
y_test[:10]
# Out:
# 67     Parkki
# 132      Pike
# 146      Pike
# 7       Bream
# 45      Roach
# 75      Perch
# 125     Perch
# 160     Smelt
# 87      Perch
# 123     Perch
# Name: Species, dtype: object

# %%
y_pred[:10]
# Out:
# array(['Parkki', 'Perch', 'Pike', 'Bream', 'Roach', 'Smelt', 'Bream',
#        'Smelt', 'Roach', 'Bream'], dtype='<U9')

# %%
model.predict_proba(x_test)
# Out:
# array([[5.41439721e-008, 6.04156477e-001, 5.79422826e-002,
#         1.44651570e-005, 3.37784571e-001, 5.44350472e-274,
#         1.02149930e-004],
#        [1.89266763e-005, 2.12775113e-005, 9.36403512e-001,
#         2.78850945e-002, 2.26464103e-006, 0.00000000e+000,
#         3.56689249e-002],
#        [3.83954135e-013, 1.70611646e-117, 2.99542703e-005,
#         9.99970046e-001, 2.45435710e-207, 0.00000000e+000,
#         4.66539002e-017],
#        [9.69905719e-001, 5.07242121e-013, 2.87579436e-002,
#         1.01853223e-005, 3.90545714e-030, 0.00000000e+000,
#         1.32615212e-003],
#        [5.61712684e-010, 2.93711971e-002, 6.84145340e-003,
#         2.76474672e-006, 9.63773605e-001, 4.82034640e-230,
#         1.09791718e-005],
#        [8.25328401e-022, 6.01789272e-017, 2.46761174e-004,
#         7.65284339e-013, 1.98487517e-017, 9.99753239e-001,
#         2.62883547e-017],
#        [5.83449630e-001, 8.87471359e-039, 2.46736370e-001,
# ...

# %% [markdown]
# # Naive Bayes with removal of outliers

# %%
def outliers(group,col,data):
    q1=data[data["Species"]==group][col].quantile(q=0.25)
    q3=data[data["Species"]==group][col].quantile(q=0.75)
    iqr=q3-q1
    lower=q1-1.5*iqr
    upper=q3+1.5*iqr
    outliers=data[(data["Species"]==group)&((data[col]>upper) | (data[col]<lower))]
    return list(outliers.index.values)

# %%
Species= list(data["Species"].unique())
columns= list(data.drop(["Species"],axis=1).columns)
out_index=[]
for col in columns:
    for group in Species:
        [out_index.append(i) for i in outliers(group,col,data)]

# %%
len(out_index)
# Out:
# 22

# %%
new_data=data.drop(index=out_index)

# %%
new_data.shape
# Out:
# (151, 5)

# %%
retval=new_data.boxplot(by="Species",figsize=(20,20))

# %%
new_data.head()
# Out:
#   Species  Weight   Height   Width  Length
# 0   Bream   242.0  11.5200  4.0200    78.6
# 1   Bream   290.0  12.4800  4.3056    81.5
# 2   Bream   290.0  12.4800  4.3056    81.5
# 3   Bream   340.0  12.3778  4.6961    81.5
# 4   Bream   363.0  12.7300  4.4555    88.8

# %%
new_data1=new_data.copy()

# %%
y=new_data["Species"]
x=new_data.drop(["Species"],axis=1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
x_train.shape,y_train.shape
# Out:
# ((120, 4), (120,))

# %%
x_test.shape,y_test.shape
# Out:
# ((31, 4), (31,))

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.7096774193548387

# %%
y_test[:10]
# Out:
# 123     Perch
# 69     Parkki
# 34      Bream
# 116     Perch
# 7       Bream
# 109     Perch
# 42      Roach
# 95      Perch
# 85      Perch
# 80      Perch
# Name: Species, dtype: object

# %%
y_pred[:10]
# Out:
# array(['Whitefish', 'Parkki', 'Bream', 'Whitefish', 'Bream', 'Perch',
#        'Roach', 'Roach', 'Roach', 'Perch'], dtype='<U9')

# %%
model.predict_proba(x_test)
# Out:
# array([[1.01035627e-001, 5.04827180e-142, 3.87126194e-001,
#         3.42669757e-002, 1.67743086e-138, 0.00000000e+000,
#         4.77571203e-001],
#        [3.68783350e-009, 9.76562810e-001, 5.57761550e-003,
#         5.07473465e-005, 1.78012263e-002, 0.00000000e+000,
#         7.59673147e-006],
#        [9.94206676e-001, 8.33585574e-144, 5.76248801e-003,
#         1.28211535e-009, 2.72209062e-194, 0.00000000e+000,
#         3.08351111e-005],
#        [1.19672524e-001, 1.79793091e-093, 3.24899001e-001,
#         3.34471684e-002, 5.49135945e-083, 0.00000000e+000,
#         5.21981306e-001],
#        [9.75499012e-001, 4.57726140e-039, 1.76304711e-002,
#         8.92325703e-006, 1.10967859e-055, 0.00000000e+000,
#         6.86159406e-003],
#        [1.32180007e-004, 2.83218563e-006, 9.11339734e-001,
#         5.86529852e-002, 2.42792189e-004, 0.00000000e+000,
#         2.96294766e-002],
#        [1.72989315e-011, 2.85070944e-002, 1.65302451e-003,
# ...

# %% [markdown]
# # Tried transforming the variables using YeoJohnson to make the features near Normal.

# %%
y=new_data1["Species"]
x=new_data1.drop(["Species"],axis=1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
import numpy as np
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer()
pt.fit(x_train)
x_train=pt.transform(x_train)
x_test=pt.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.7419354838709677

# %% [markdown]
# Naive Bayes is sensitive to outliers as with outliers In Gaussian Naive Bayes, outliers will affect the shape of the Gaussian distribution and have the usual effects on the mean which will lead to low accuracy score(45.45) whereas with removal of outliers and after applying YeoJohnson power transformer the accuracy score increased(74.1) and in this case YeoJohnson gave good accuracy score as compared to Standard Scaler

# %% [markdown]
# # With removal of outliers and applying YeoJohnson power transformer train1,train2

# %%
train1,train2,y_train1,y_train2 = train_test_split(x_train,y_train,test_size=0.5, random_state=0)

# %%
train1.shape,y_train1.shape
# Out:
# ((60, 4), (60,))

# %%
train2.shape,y_train2.shape
# Out:
# ((60, 4), (60,))

# %% [markdown]
# ## Normal fit

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(train1,y_train1)
# Out:
# GaussianNB()

# %%
model.score(x_test,y_test)
# Out:
# 0.6774193548387096

# %% [markdown]
# ## Partial fit

# %%
from sklearn.naive_bayes import GaussianNB
model1 = GaussianNB()
model1.partial_fit(train2,y_train2,classes=['Smelt','Perch', 'Bream', 'Roach','Pike','Whitefish','Parkki'])
# Out:
# GaussianNB()

# %%
model1.score(x_test,y_test)
# Out:
# 0.8064516129032258

# %% [markdown]
# condition 1: tried to fit the model with 80% train set got accuracy score of 74.19 <br>
# condition 2: tried to fit the model with 40% train (train1) set got accuracy score of 67.74 <br>
# condition 3: tried to partial_fit the model with 40% train (train2) set got accuracy score of 80.64

# %% [markdown]
# # Independent Dependent variables

# %%
new_data1.head()
# Out:
#   Species  Weight   Height   Width  Length
# 0   Bream   242.0  11.5200  4.0200    78.6
# 1   Bream   290.0  12.4800  4.3056    81.5
# 2   Bream   290.0  12.4800  4.3056    81.5
# 3   Bream   340.0  12.3778  4.6961    81.5
# 4   Bream   363.0  12.7300  4.4555    88.8

# %%
import seaborn as sns
corr_matrix=new_data1.corr()
sns.heatmap(corr_matrix, annot=True, cmap='YlGnBu');

# %% [markdown]
# # Independent

# %%
y=data["Species"]
x=data.drop(["Species","Width","Weight"],axis=1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
import numpy as np
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer()
pt.fit(x_train)
x_train=pt.transform(x_train)
x_test=pt.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.5151515151515151

# %% [markdown]
# # Dependent

# %%
y=data["Species"]
x=data.drop(["Species","Width","Height"],axis=1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
import numpy as np
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer()
pt.fit(x_train)
x_train=pt.transform(x_train)
x_test=pt.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.45454545454545453

# %% [markdown]
# Model performance is better if the attributes show low correlation with each other (i.e. when they are independent)
